# %%
#Clases
from graphviz import Digraph
import os
class Nodo:
    def __init__(self, valor, peso, tipo):
        self.valor = valor #Nombre de la imagen
        self.peso_en_bytes= peso #Peso en bytes
        self.izquierda = None
        self.derecha = None
        self.altura = 1
        self.tipo = tipo

class ArbolBinario:
    def __init__(self):
        self.raiz = None

    def altura(self, nodo):
            if nodo is None:
                return 0
            return nodo.altura

    def balance(self, nodo):
        if nodo is None:
            return 0
        return self.altura(nodo.izquierda) - self.altura(nodo.derecha)

    def _rotar_derecha(self, y):
        x = y.izquierda
        T2 = x.derecha

        x.derecha = y
        y.izquierda = T2

        y.altura = 1 + max(self.altura(y.izquierda), self.altura(y.derecha))
        x.altura = 1 + max(self.altura(x.izquierda), self.altura(x.derecha))

        return x

    def _rotar_izquierda(self, x):
        y = x.derecha
        T2 = y.izquierda

        y.izquierda = x
        x.derecha = T2

        x.altura = 1 + max(self.altura(x.izquierda), self.altura(x.derecha))
        y.altura = 1 + max(self.altura(y.izquierda), self.altura(y.derecha))

        return y


    def _balance(self, nodo, valor, peso, tipo):
        if nodo is None:
            return Nodo(valor,peso, tipo)

        if valor < nodo.valor:
            nodo.izquierda = self._balance(nodo.izquierda, valor, peso, tipo)
        elif valor > nodo.valor:
            nodo.derecha = self._balance(nodo.derecha, valor, peso, tipo)
        else:
            return nodo  # Evitar duplicados

        nodo.altura = 1 + max(self.altura(nodo.izquierda), self.altura(nodo.derecha))

        balance = self.altura(nodo.izquierda) - self.altura(nodo.derecha)

        # Casos de desequilibrio

        # Caso izquierda izquierda
        if balance > 1 and valor < nodo.izquierda.valor:
            return self._rotar_derecha(nodo)

        # Caso derecha derecha
        if balance < -1 and valor > nodo.derecha.valor:
            return self._rotar_izquierda(nodo)

        # Caso izquierda derecha
        if balance > 1 and valor > nodo.izquierda.valor:
            nodo.izquierda = self._rotar_izquierda(nodo.izquierda)
            return self._rotar_derecha(nodo)

        # Caso derecha izquierda
        if balance < -1 and valor < nodo.derecha.valor:
            nodo.derecha = self._rotar_derecha(nodo.derecha)
            return self._rotar_izquierda(nodo)

        return nodo

    def insertar(self, valor, peso, tipo):
        self.raiz = self._balance(self.raiz, valor, peso, tipo)
        #self.graficar_arbol()  # Gráfica el árbol después de cada inserción

    def eliminar_nodo(self, valor):
        if not self.buscar_nodo(valor):
            print("El nodo no existe, no se puede eliminar.")
            return
        self.raiz = self._eliminar_nodo(self.raiz, valor)
        self.graficar_arbol()  # Gráfica el árbol después de cada eliminación

    def _eliminar_nodo(self, nodo, valor):
        if nodo is None:
            return None

        # Buscar el nodo que se desea eliminar
        if valor < nodo.valor:
            nodo.izquierda = self._eliminar_nodo(nodo.izquierda, valor)
        elif valor > nodo.valor:
            nodo.derecha = self._eliminar_nodo(nodo.derecha, valor)
        else:
            # Caso: Nodo a eliminar encontrado

            # Nodo con un solo hijo o sin hijos
            if nodo.izquierda is None:
                return nodo.derecha
            elif nodo.derecha is None:
                return nodo.izquierda

            # Nodo con dos hijos
            sucesor = self._encontrar_sucesor(nodo.derecha)
            nodo.valor = sucesor.valor
            nodo.peso_en_bytes = sucesor.peso_en_bytes
            nodo.derecha = self._eliminar_nodo(nodo.derecha, sucesor.valor)

        # Actualizar altura del nodo actual
        nodo.altura = 1 + max(self.altura(nodo.izquierda), self.altura(nodo.derecha))

        # Rebalancear el árbol después de la eliminación
        return self._balance(nodo, valor, 0,"")

    def _encontrar_sucesor(self, nodo):
        while nodo.izquierda:
            nodo = nodo.izquierda
        return nodo


    def buscar_nodo(self, metrica):
        return self._buscar_nodo(self.raiz, metrica)

    def _buscar_nodo(self, nodo, metrica):
        if nodo is None or nodo.valor == metrica:
            return nodo
        elif metrica < nodo.valor:
            return self._buscar_nodo(nodo.izquierda, metrica)
        else:
            return self._buscar_nodo(nodo.derecha, metrica)


    def buscar_por_tipo_y_peso(self, tipo, peso_min, peso_max):
        resultados = []
        self._buscar_por_tipo_y_peso(self.raiz, tipo, peso_min, peso_max, resultados)
        return resultados

    def _buscar_por_tipo_y_peso(self, nodo, tipo, peso_min, peso_max, resultados):
        if nodo is None:
            return

        # Si el nodo actual cumple con los criterios, se añade a la lista de resultados
        if nodo.tipo == tipo and peso_min <= nodo.peso_en_bytes < peso_max:
            resultados.append(nodo)

        # Dado que el árbol no está organizado por tipo o peso, necesitamos recorrer todos los nodos
        self._buscar_por_tipo_y_peso(nodo.izquierda, tipo, peso_min, peso_max, resultados)
        self._buscar_por_tipo_y_peso(nodo.derecha, tipo, peso_min, peso_max, resultados)


    def graficar_arbol(self):
        if not self.raiz:
            print("El árbol está vacío.")
            return

        dot = Digraph(comment='Árbol Binario')

        def agregar_nodos_edges(nodo):
            if nodo:
                dot.node(name=str(nodo.valor), label=f'{nodo.valor}\n{str(nodo.peso_en_bytes)} bytes\n{str(nodo.tipo)}')

                if nodo.izquierda:
                    dot.edge(str(nodo.valor), str(nodo.izquierda.valor))
                    agregar_nodos_edges(nodo.izquierda)

                if nodo.derecha:
                    dot.edge(str(nodo.valor), str(nodo.derecha.valor))
                    agregar_nodos_edges(nodo.derecha)

        agregar_nodos_edges(self.raiz)

        dot.render(filename=os.path.abspath("arbol_binario"), view=False, format='svg')  # Guarda y muestra el árbol

    def _graficar_nodo(self, dot, nodo):
        if nodo:
            dot.node(str(id(nodo)), f'{nodo.valor}\n({nodo.peso_en_bytes} bytes)\nType: {nodo.tipo}')
            if nodo.izquierda:
                dot.edge(str(id(nodo)), str(id(nodo.izquierda)), label='Izquierda')
                self._graficar_nodo(dot, nodo.izquierda)
            if nodo.derecha:
                dot.edge(str(id(nodo)), str(id(nodo.derecha)), label='Derecha')
                self._graficar_nodo(dot, nodo.derecha)

    def obtener_categorias_disponibles(self):
        categorias = set()
        def recorrer(nodo):
            if nodo:
                categorias.add(nodo.tipo)
                recorrer(nodo.izquierda)
                recorrer(nodo.derecha)
        recorrer(self.raiz)
        return list(categorias)

    def mostrar_recorrido_por_niveles(self):
        def imprimir_nivel(nodo, nivel):
            if nodo is None:
                return
            if nivel == 1:
                print(nodo.valor, end=" ")
            elif nivel > 1:
                imprimir_nivel(nodo.izquierda, nivel - 1)
                imprimir_nivel(nodo.derecha, nivel - 1)

        altura = self.obtener_altura(self.raiz)
        for i in range(1, altura + 1):
            imprimir_nivel(self.raiz, i)
            print()

    def obtener_altura(self, nodo):
        if nodo is None:
            return 0
        else:
            altura_izquierda = self.obtener_altura(nodo.izquierda)
            altura_derecha = self.obtener_altura(nodo.derecha)
            return max(altura_izquierda, altura_derecha) + 1

    def obtener_nivel(self, valor, nodo, nivel=0):
      if nodo is None:
          return 0
      if nodo.valor == valor:
          return nivel
      nivel_inferior = self.obtener_nivel(valor, nodo.izquierda, nivel + 1)
      if nivel_inferior != 0:
          return nivel_inferior
      nivel_inferior = self.obtener_nivel(valor, nodo.derecha, nivel + 1)
      return nivel_inferior

    def encontrar_relaciones(self, valor):
        def buscar_y_relacionar(nodo, valor_busqueda, ancestros=[]):
            if nodo is None:
                return None, None, None
            if nodo.valor == valor_busqueda:
                padre = ancestros[-1] if len(ancestros) >= 1 else None
                abuelo = ancestros[-2] if len(ancestros) >= 2 else None
                tio = None
                if abuelo:
                    if abuelo.izquierda is not None and abuelo.izquierda != padre:
                        tio = abuelo.izquierda
                    elif abuelo.derecha is not None and abuelo.derecha != padre:
                        tio = abuelo.derecha
                return padre, abuelo, tio
            else:
                # Intenta buscar primero en la izquierda, y si no se encuentra, en la derecha
                result = buscar_y_relacionar(nodo.izquierda, valor_busqueda, ancestros + [nodo])
                if result == (None, None, None):  # Si no se encuentra en la izquierda, busca en la derecha
                    return buscar_y_relacionar(nodo.derecha, valor_busqueda, ancestros + [nodo])
                return result

        return buscar_y_relacionar(self.raiz, valor)

# %%
#ABRIR ZIP FILE


import zipfile
import os

# Nombre del archivo ZIP cargado
zip_filename = os.path.abspath("data.zip")

# Ruta de destino para la extracción
extract_path = os.path.abspath("extracted")

# Crea el directorio de extracción si no existe
os.makedirs(extract_path, exist_ok=True)

# Descomprime el archivo ZIP
with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
#LECTURA DE LAS IMAGENES

from PIL import Image

def leer_carpeta_con_imagenes(carpeta_raiz):
    for carpeta_actual, subcarpetas, archivos in os.walk(carpeta_raiz):
        for archivo in archivos:
            if archivo.lower().endswith((".bmp", ".jpg", ".jpeg", ".png")):
                ruta_completa = os.path.join(carpeta_actual, archivo)
                procesar_imagen(ruta_completa)

def procesar_imagen(ruta_imagen):
    imagen = Image.open(ruta_imagen)

    print(obtener_nombre_sin_extension(ruta_imagen))

    peso_en_bytes = obtener_peso_en_bytes(ruta_imagen)
    print("Peso de la imagen en bytes:", peso_en_bytes)

    tipo = os.path.basename(os.path.dirname(ruta_imagen))
    print("Carpeta de origen:", tipo)

    arbol.insertar(obtener_nombre_sin_extension(ruta_imagen), peso_en_bytes, tipo)


    imagen.close()

def obtener_peso_en_bytes(ruta_imagen):
    return os.path.getsize(ruta_imagen)


def obtener_nombre_sin_extension(ruta_archivo):
    nombre_base = os.path.basename(ruta_archivo)
    return os.path.splitext(nombre_base)[0]


# Ruta de la carpeta principal que contiene las subcarpetas con imágenes
carpeta_principal = os.path.abspath("extracted")

arbol= ArbolBinario()

# Llama a la función para leer la carpeta con imágenes
leer_carpeta_con_imagenes(carpeta_principal)
#arbol.eliminar_nodo("0005")
arbol.graficar_arbol()
# Out:
# bike_001
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_002
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_003
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_004
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_005
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_006
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_007
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_008
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_009
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_010
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_011
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_012
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_013
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_014
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_015
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_016
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_017
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_018
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_019
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_020
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_021
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_022
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_023
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_024
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_025
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_026
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_027
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_028
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_029
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_030
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_031
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_032
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_033
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_034
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_035
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_036
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_037
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_038
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_039
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_040
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_041
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_042
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_043
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_044
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_045
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_046
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_047
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_048
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_049
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_050
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_051
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_052
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_053
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_054
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_055
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_056
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_057
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_058
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_059
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_060
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_061
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_062
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_063
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_064
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_065
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_066
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_067
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_068
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_069
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_070
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_071
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_072
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_073
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_074
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_075
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_076
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_077
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_078
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_079
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_080
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_081
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_082
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_083
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_084
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_085
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_086
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_087
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_088
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_089
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_090
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_091
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_092
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_093
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_094
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_095
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_096
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_097
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_098
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_099
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_100
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_101
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_102
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_103
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_104
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_105
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_106
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_107
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_108
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_109
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_110
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_111
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_112
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_113
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_114
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_115
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_116
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_117
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_118
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_119
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_120
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_121
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_122
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_123
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_124
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_125
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_126
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_127
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_128
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_129
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_130
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_131
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_132
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_133
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_134
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_135
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_136
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_137
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_138
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_139
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_140
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_141
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_142
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_143
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_144
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_145
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_146
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_147
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_148
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_149
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_150
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_151
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_152
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_153
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_154
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_155
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_156
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_157
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_158
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_159
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_160
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_161
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_162
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_163
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_164
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_165
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_166
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_167
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_168
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_169
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_170
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_171
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_172
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_173
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_174
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_175
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_176
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_177
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_178
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_179
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_180
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_181
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_182
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_183
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_184
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_185
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_186
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_187
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_188
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_189
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_190
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_191
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_192
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_193
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_194
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_195
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_196
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_197
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_198
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_199
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_200
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_201
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_202
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_203
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_204
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_205
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_206
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_207
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_208
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_209
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_210
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_211
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_212
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_213
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_214
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_215
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_216
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_217
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_218
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_219
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_220
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_221
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_222
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_223
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_224
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_225
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_226
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_227
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_228
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_229
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_230
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_231
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_232
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_233
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_234
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_235
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_236
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_237
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_238
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_239
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_240
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_241
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_242
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_243
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_244
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_245
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_246
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_247
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_248
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_249
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_250
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_251
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_252
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_253
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_254
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_255
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_256
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_257
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_258
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_259
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_260
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_261
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_262
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_263
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_264
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_265
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_266
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_267
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_268
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_269
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_270
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_271
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_272
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_273
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_274
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_275
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_276
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_277
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_278
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_279
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_280
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_281
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_282
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_283
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_284
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_285
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_286
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_287
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_288
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_289
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_290
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_291
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_292
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_293
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_294
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_295
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_296
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_297
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_298
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_299
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_300
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_301
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_302
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_303
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_304
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_305
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_306
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_307
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_308
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_309
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_310
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_311
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_312
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_313
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_314
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_315
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_316
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_317
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_318
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_319
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_320
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_321
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_322
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_323
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_324
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_325
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_326
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_327
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_328
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_329
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_330
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_331
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_332
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_333
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_334
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_335
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_336
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_337
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_338
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_339
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_340
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_341
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_342
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_343
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_344
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_345
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_346
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_347
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_348
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_349
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_350
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_351
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_352
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_353
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_354
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_355
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_356
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_357
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_358
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_359
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_360
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_361
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_362
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_363
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_364
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# bike_365
# Peso de la imagen en bytes: 921654
# Carpeta de origen: bike
# carsgraz_001
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_002
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_003
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_004
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_005
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_006
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_007
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_008
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_009
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_010
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_011
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_012
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_013
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_014
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_015
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_016
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_017
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_018
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_019
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_020
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_021
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_022
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_023
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_024
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_025
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_026
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_027
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_028
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_029
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_030
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_031
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_032
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_033
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_034
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_035
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_036
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_037
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_038
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_039
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_040
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_041
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_042
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_043
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_044
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_045
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_046
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_047
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_048
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_049
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_050
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_051
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_052
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_053
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_054
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_055
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_056
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_057
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_058
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_059
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_060
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_061
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_062
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_063
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_064
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_065
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_066
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_067
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_068
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_069
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_070
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_071
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_072
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_073
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_074
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_075
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_076
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_077
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_078
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_079
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_080
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_081
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_082
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_083
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_084
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_085
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_086
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_087
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_088
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_089
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_090
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_091
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_092
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_093
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_094
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_095
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_096
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_097
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_098
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_099
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_100
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_101
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_102
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_103
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_104
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_105
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_106
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_107
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_108
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_109
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_110
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_111
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_112
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_113
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_114
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_115
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_116
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_117
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_118
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_119
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_120
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_121
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_122
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_123
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_124
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_125
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_126
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_127
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_128
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_129
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_130
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_131
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_132
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_133
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_134
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_135
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_136
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_137
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_138
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_139
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_140
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_141
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_142
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_143
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_144
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_145
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_146
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_147
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_148
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_149
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_150
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_151
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_152
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_153
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_154
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_155
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_156
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_157
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_158
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_159
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_160
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_161
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_162
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_163
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_164
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_165
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_166
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_167
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_168
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_169
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_170
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_171
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_172
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_173
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_174
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_175
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_176
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_177
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_178
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_179
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_180
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_181
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_182
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_183
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_184
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_185
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_186
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_187
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_188
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_189
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_190
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_191
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_192
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_193
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_194
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_195
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_196
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_197
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_198
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_199
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_200
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_201
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_202
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_203
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_204
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_205
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_206
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_207
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_208
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_209
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_210
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_211
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_212
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_213
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_214
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_215
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_216
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_217
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_218
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_219
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_220
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_221
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_222
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_223
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_224
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_225
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_226
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_227
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_228
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_229
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_230
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_231
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_232
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_233
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_234
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_235
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_236
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_237
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_238
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_239
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_240
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_241
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_242
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_243
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_244
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_245
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_246
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_247
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_248
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_249
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_250
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_251
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_252
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_253
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_254
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_255
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_256
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_257
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_258
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_259
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_260
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_261
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_262
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_263
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_264
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_265
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_266
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_267
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_268
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_269
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_270
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_271
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_272
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_273
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_274
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_275
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_276
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_277
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_278
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_279
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_280
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_281
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_282
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_283
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_284
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_285
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_286
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_287
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_288
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_289
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_290
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_291
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_292
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_293
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_294
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_295
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_296
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_297
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_298
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_299
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_300
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_301
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_302
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_303
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_304
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_305
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_306
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_307
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_308
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_309
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_310
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_311
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_312
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_313
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_314
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_315
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_316
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_317
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_318
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_319
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_320
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_321
# Peso de la imagen en bytes: 921654
# Carpeta de origen: cars
# carsgraz_322
# Peso de la imagen en bytes: 921654
# ...
# Carpeta de origen: horses
# horse-71
# Peso de la imagen en bytes: 18207
# Carpeta de origen: horses
# horse-72
# Peso de la imagen en bytes: 15793
# Carpeta de origen: horses
# horse-73
# Peso de la imagen en bytes: 21536
# Carpeta de origen: horses
# horse-74
# Peso de la imagen en bytes: 24691
# Carpeta de origen: horses
# horse-75
# Peso de la imagen en bytes: 8309
# Carpeta de origen: horses
# horse-76
# Peso de la imagen en bytes: 22176
# Carpeta de origen: horses
# horse-77
# Peso de la imagen en bytes: 21209
# Carpeta de origen: horses
# horse-78
# Peso de la imagen en bytes: 32087
# Carpeta de origen: horses
# horse-79
# Peso de la imagen en bytes: 17414
# Carpeta de origen: horses
# horse-8
# Peso de la imagen en bytes: 25299
# Carpeta de origen: horses
# horse-80
# Peso de la imagen en bytes: 17356
# Carpeta de origen: horses
# horse-81
# Peso de la imagen en bytes: 19515
# Carpeta de origen: horses
# horse-82
# Peso de la imagen en bytes: 17948
# Carpeta de origen: horses
# horse-83
# Peso de la imagen en bytes: 22517
# Carpeta de origen: horses
# horse-84
# Peso de la imagen en bytes: 22430
# Carpeta de origen: horses
# horse-85
# Peso de la imagen en bytes: 16269
# Carpeta de origen: horses
# horse-86
# Peso de la imagen en bytes: 16733
# Carpeta de origen: horses
# horse-87
# Peso de la imagen en bytes: 19792
# Carpeta de origen: horses
# horse-88
# Peso de la imagen en bytes: 16023
# Carpeta de origen: horses
# horse-89
# Peso de la imagen en bytes: 19515
# Carpeta de origen: horses
# horse-9
# Peso de la imagen en bytes: 117808
# Carpeta de origen: horses
# horse-90
# Peso de la imagen en bytes: 20564
# Carpeta de origen: horses
# horse-91
# Peso de la imagen en bytes: 11851
# Carpeta de origen: horses
# horse-92
# Peso de la imagen en bytes: 11851
# Carpeta de origen: horses
# horse-93
# Peso de la imagen en bytes: 9738
# Carpeta de origen: horses
# horse-94
# Peso de la imagen en bytes: 14372
# Carpeta de origen: horses
# horse-95
# Peso de la imagen en bytes: 16315
# Carpeta de origen: horses
# horse-96
# Peso de la imagen en bytes: 9062
# Carpeta de origen: horses
# horse-97
# Peso de la imagen en bytes: 18536
# Carpeta de origen: horses
# horse-98
# Peso de la imagen en bytes: 28536
# Carpeta de origen: horses
# horse-99
# Peso de la imagen en bytes: 22885
# Carpeta de origen: horses
# rider-1
# Peso de la imagen en bytes: 14789
# Carpeta de origen: human
# rider-10
# Peso de la imagen en bytes: 17650
# Carpeta de origen: human
# rider-100
# Peso de la imagen en bytes: 20179
# Carpeta de origen: human
# rider-101
# Peso de la imagen en bytes: 19373
# Carpeta de origen: human
# rider-102
# Peso de la imagen en bytes: 17442
# Carpeta de origen: human
# rider-103
# Peso de la imagen en bytes: 26945
# Carpeta de origen: human
# rider-104
# Peso de la imagen en bytes: 11630
# Carpeta de origen: human
# rider-105
# Peso de la imagen en bytes: 22005
# Carpeta de origen: human
# rider-106
# Peso de la imagen en bytes: 18416
# Carpeta de origen: human
# rider-107
# Peso de la imagen en bytes: 14794
# Carpeta de origen: human
# rider-108
# Peso de la imagen en bytes: 16275
# Carpeta de origen: human
# rider-109
# Peso de la imagen en bytes: 17650
# Carpeta de origen: human
# rider-11
# Peso de la imagen en bytes: 12323
# Carpeta de origen: human
# rider-110
# Peso de la imagen en bytes: 7046
# Carpeta de origen: human
# rider-111
# Peso de la imagen en bytes: 9653
# Carpeta de origen: human
# rider-112
# Peso de la imagen en bytes: 17579
# Carpeta de origen: human
# rider-113
# Peso de la imagen en bytes: 6487
# Carpeta de origen: human
# rider-114
# Peso de la imagen en bytes: 21469
# Carpeta de origen: human
# rider-115
# Peso de la imagen en bytes: 23576
# Carpeta de origen: human
# rider-116
# Peso de la imagen en bytes: 18072
# Carpeta de origen: human
# rider-117
# Peso de la imagen en bytes: 10498
# Carpeta de origen: human
# rider-118
# Peso de la imagen en bytes: 14498
# Carpeta de origen: human
# rider-119
# Peso de la imagen en bytes: 8571
# Carpeta de origen: human
# rider-12
# Peso de la imagen en bytes: 21692
# Carpeta de origen: human
# rider-120
# Peso de la imagen en bytes: 27400
# Carpeta de origen: human
# rider-121
# Peso de la imagen en bytes: 15005
# Carpeta de origen: human
# rider-122
# Peso de la imagen en bytes: 24287
# Carpeta de origen: human
# rider-123
# Peso de la imagen en bytes: 18284
# Carpeta de origen: human
# rider-124
# Peso de la imagen en bytes: 8894
# Carpeta de origen: human
# rider-125
# Peso de la imagen en bytes: 17986
# Carpeta de origen: human
# rider-126
# Peso de la imagen en bytes: 18656
# Carpeta de origen: human
# rider-127
# Peso de la imagen en bytes: 15005
# Carpeta de origen: human
# rider-128
# Peso de la imagen en bytes: 7944
# Carpeta de origen: human
# rider-129
# Peso de la imagen en bytes: 10289
# Carpeta de origen: human
# rider-13
# Peso de la imagen en bytes: 9180
# Carpeta de origen: human
# rider-130
# Peso de la imagen en bytes: 12480
# Carpeta de origen: human
# rider-131
# Peso de la imagen en bytes: 14389
# Carpeta de origen: human
# rider-132
# Peso de la imagen en bytes: 15098
# Carpeta de origen: human
# rider-133
# Peso de la imagen en bytes: 15713
# Carpeta de origen: human
# rider-134
# Peso de la imagen en bytes: 17297
# Carpeta de origen: human
# rider-135
# Peso de la imagen en bytes: 25432
# Carpeta de origen: human
# rider-136
# Peso de la imagen en bytes: 30077
# Carpeta de origen: human
# rider-137
# Peso de la imagen en bytes: 12307
# Carpeta de origen: human
# rider-138
# Peso de la imagen en bytes: 22008
# Carpeta de origen: human
# rider-139
# Peso de la imagen en bytes: 18507
# Carpeta de origen: human
# rider-14
# Peso de la imagen en bytes: 12138
# Carpeta de origen: human
# rider-140
# Peso de la imagen en bytes: 23037
# Carpeta de origen: human
# rider-141
# Peso de la imagen en bytes: 12491
# Carpeta de origen: human
# rider-142
# Peso de la imagen en bytes: 20451
# Carpeta de origen: human
# rider-143
# Peso de la imagen en bytes: 15224
# Carpeta de origen: human
# rider-144
# Peso de la imagen en bytes: 11631
# Carpeta de origen: human
# rider-145
# Peso de la imagen en bytes: 14373
# Carpeta de origen: human
# rider-146
# Peso de la imagen en bytes: 19661
# Carpeta de origen: human
# rider-147
# Peso de la imagen en bytes: 30077
# Carpeta de origen: human
# rider-148
# Peso de la imagen en bytes: 13571
# Carpeta de origen: human
# rider-149
# Peso de la imagen en bytes: 11489
# Carpeta de origen: human
# rider-15
# Peso de la imagen en bytes: 18481
# Carpeta de origen: human
# rider-150
# Peso de la imagen en bytes: 16547
# Carpeta de origen: human
# rider-151
# Peso de la imagen en bytes: 22734
# Carpeta de origen: human
# rider-152
# Peso de la imagen en bytes: 20299
# Carpeta de origen: human
# rider-153
# Peso de la imagen en bytes: 17718
# Carpeta de origen: human
# rider-154
# Peso de la imagen en bytes: 19978
# Carpeta de origen: human
# rider-155
# Peso de la imagen en bytes: 19160
# Carpeta de origen: human
# rider-156
# Peso de la imagen en bytes: 15817
# Carpeta de origen: human
# rider-157
# Peso de la imagen en bytes: 12697
# Carpeta de origen: human
# rider-158
# Peso de la imagen en bytes: 19739
# Carpeta de origen: human
# rider-159
# Peso de la imagen en bytes: 28064
# Carpeta de origen: human
# rider-16
# Peso de la imagen en bytes: 18391
# Carpeta de origen: human
# rider-160
# Peso de la imagen en bytes: 25478
# Carpeta de origen: human
# rider-161
# Peso de la imagen en bytes: 19836
# Carpeta de origen: human
# rider-162
# Peso de la imagen en bytes: 11059
# Carpeta de origen: human
# rider-163
# Peso de la imagen en bytes: 21399
# Carpeta de origen: human
# rider-164
# Peso de la imagen en bytes: 11052
# Carpeta de origen: human
# rider-165
# Peso de la imagen en bytes: 16172
# Carpeta de origen: human
# rider-166
# Peso de la imagen en bytes: 10963
# Carpeta de origen: human
# rider-167
# Peso de la imagen en bytes: 8091
# Carpeta de origen: human
# rider-168
# Peso de la imagen en bytes: 26116
# Carpeta de origen: human
# rider-169
# Peso de la imagen en bytes: 21334
# Carpeta de origen: human
# rider-17
# Peso de la imagen en bytes: 16673
# Carpeta de origen: human
# rider-170
# Peso de la imagen en bytes: 18201
# Carpeta de origen: human
# rider-171
# Peso de la imagen en bytes: 14899
# Carpeta de origen: human
# rider-172
# Peso de la imagen en bytes: 10617
# Carpeta de origen: human
# rider-173
# Peso de la imagen en bytes: 12004
# Carpeta de origen: human
# rider-174
# Peso de la imagen en bytes: 29744
# Carpeta de origen: human
# rider-175
# Peso de la imagen en bytes: 22190
# Carpeta de origen: human
# rider-176
# Peso de la imagen en bytes: 14580
# Carpeta de origen: human
# rider-177
# Peso de la imagen en bytes: 14519
# Carpeta de origen: human
# rider-178
# Peso de la imagen en bytes: 8746
# Carpeta de origen: human
# rider-179
# Peso de la imagen en bytes: 24838
# Carpeta de origen: human
# rider-18
# Peso de la imagen en bytes: 17518
# Carpeta de origen: human
# rider-180
# Peso de la imagen en bytes: 22073
# Carpeta de origen: human
# rider-181
# Peso de la imagen en bytes: 12541
# Carpeta de origen: human
# rider-182
# Peso de la imagen en bytes: 26195
# Carpeta de origen: human
# rider-183
# Peso de la imagen en bytes: 21211
# Carpeta de origen: human
# rider-184
# Peso de la imagen en bytes: 20385
# Carpeta de origen: human
# rider-185
# Peso de la imagen en bytes: 22738
# Carpeta de origen: human
# rider-186
# Peso de la imagen en bytes: 20671
# Carpeta de origen: human
# rider-187
# Peso de la imagen en bytes: 26436
# Carpeta de origen: human
# rider-188
# Peso de la imagen en bytes: 19775
# Carpeta de origen: human
# rider-189
# Peso de la imagen en bytes: 11781
# Carpeta de origen: human
# rider-19
# Peso de la imagen en bytes: 24218
# Carpeta de origen: human
# rider-190
# Peso de la imagen en bytes: 25190
# Carpeta de origen: human
# rider-191
# Peso de la imagen en bytes: 4565
# Carpeta de origen: human
# rider-192
# Peso de la imagen en bytes: 12194
# Carpeta de origen: human
# rider-193
# Peso de la imagen en bytes: 17297
# Carpeta de origen: human
# rider-194
# Peso de la imagen en bytes: 5346
# Carpeta de origen: human
# rider-195
# Peso de la imagen en bytes: 18338
# Carpeta de origen: human
# rider-196
# Peso de la imagen en bytes: 21399
# Carpeta de origen: human
# rider-197
# Peso de la imagen en bytes: 11212
# Carpeta de origen: human
# rider-198
# Peso de la imagen en bytes: 15773
# Carpeta de origen: human
# rider-199
# Peso de la imagen en bytes: 9370
# Carpeta de origen: human
# rider-2
# Peso de la imagen en bytes: 196223
# Carpeta de origen: human
# rider-20
# Peso de la imagen en bytes: 9627
# Carpeta de origen: human
# rider-200
# Peso de la imagen en bytes: 38307
# Carpeta de origen: human
# rider-201
# Peso de la imagen en bytes: 709112
# Carpeta de origen: human
# rider-202
# Peso de la imagen en bytes: 709112
# Carpeta de origen: human
# rider-21
# Peso de la imagen en bytes: 11630
# Carpeta de origen: human
# rider-22
# Peso de la imagen en bytes: 24722
# Carpeta de origen: human
# rider-23
# Peso de la imagen en bytes: 5759
# Carpeta de origen: human
# rider-24
# Peso de la imagen en bytes: 19617
# Carpeta de origen: human
# rider-25
# Peso de la imagen en bytes: 23340
# Carpeta de origen: human
# rider-26
# Peso de la imagen en bytes: 18507
# Carpeta de origen: human
# rider-27
# Peso de la imagen en bytes: 17579
# Carpeta de origen: human
# rider-28
# Peso de la imagen en bytes: 14286
# Carpeta de origen: human
# rider-29
# Peso de la imagen en bytes: 19239
# Carpeta de origen: human
# rider-3
# Peso de la imagen en bytes: 44907
# Carpeta de origen: human
# rider-30
# Peso de la imagen en bytes: 17718
# Carpeta de origen: human
# rider-31
# Peso de la imagen en bytes: 22115
# Carpeta de origen: human
# rider-32
# Peso de la imagen en bytes: 11210
# Carpeta de origen: human
# rider-33
# Peso de la imagen en bytes: 19608
# Carpeta de origen: human
# rider-34
# Peso de la imagen en bytes: 22511
# Carpeta de origen: human
# rider-35
# Peso de la imagen en bytes: 19978
# Carpeta de origen: human
# rider-36
# Peso de la imagen en bytes: 16385
# Carpeta de origen: human
# rider-37
# Peso de la imagen en bytes: 16911
# Carpeta de origen: human
# rider-38
# Peso de la imagen en bytes: 14553
# Carpeta de origen: human
# rider-39
# Peso de la imagen en bytes: 21353
# Carpeta de origen: human
# rider-4
# Peso de la imagen en bytes: 35352
# Carpeta de origen: human
# rider-40
# Peso de la imagen en bytes: 20385
# Carpeta de origen: human
# rider-41
# Peso de la imagen en bytes: 19346
# Carpeta de origen: human
# rider-42
# Peso de la imagen en bytes: 20203
# Carpeta de origen: human
# rider-43
# Peso de la imagen en bytes: 19584
# Carpeta de origen: human
# rider-44
# Peso de la imagen en bytes: 9394
# Carpeta de origen: human
# rider-45
# Peso de la imagen en bytes: 17144
# Carpeta de origen: human
# rider-46
# Peso de la imagen en bytes: 17757
# Carpeta de origen: human
# rider-47
# Peso de la imagen en bytes: 27926
# Carpeta de origen: human
# rider-48
# Peso de la imagen en bytes: 20295
# Carpeta de origen: human
# rider-49
# Peso de la imagen en bytes: 15713
# Carpeta de origen: human
# rider-5
# Peso de la imagen en bytes: 154449
# Carpeta de origen: human
# rider-50
# Peso de la imagen en bytes: 28064
# Carpeta de origen: human
# rider-51
# Peso de la imagen en bytes: 18850
# Carpeta de origen: human
# rider-52
# Peso de la imagen en bytes: 19091
# Carpeta de origen: human
# rider-53
# Peso de la imagen en bytes: 18853
# Carpeta de origen: human
# rider-54
# Peso de la imagen en bytes: 13571
# Carpeta de origen: human
# rider-55
# Peso de la imagen en bytes: 8108
# Carpeta de origen: human
# rider-56
# Peso de la imagen en bytes: 19177
# Carpeta de origen: human
# rider-57
# Peso de la imagen en bytes: 17982
# Carpeta de origen: human
# rider-58
# Peso de la imagen en bytes: 16915
# Carpeta de origen: human
# rider-59
# Peso de la imagen en bytes: 15283
# Carpeta de origen: human
# rider-6
# Peso de la imagen en bytes: 31495
# Carpeta de origen: human
# rider-60
# Peso de la imagen en bytes: 13998
# Carpeta de origen: human
# rider-61
# Peso de la imagen en bytes: 19654
# Carpeta de origen: human
# rider-62
# Peso de la imagen en bytes: 8530
# Carpeta de origen: human
# rider-63
# Peso de la imagen en bytes: 26011
# Carpeta de origen: human
# rider-64
# Peso de la imagen en bytes: 16120
# Carpeta de origen: human
# rider-65
# Peso de la imagen en bytes: 25274
# Carpeta de origen: human
# rider-66
# Peso de la imagen en bytes: 24657
# Carpeta de origen: human
# rider-67
# Peso de la imagen en bytes: 18656
# Carpeta de origen: human
# rider-68
# Peso de la imagen en bytes: 9811
# Carpeta de origen: human
# rider-69
# Peso de la imagen en bytes: 10212
# Carpeta de origen: human
# rider-7
# Peso de la imagen en bytes: 31495
# Carpeta de origen: human
# rider-70
# Peso de la imagen en bytes: 14520
# Carpeta de origen: human
# rider-71
# Peso de la imagen en bytes: 22734
# Carpeta de origen: human
# rider-72
# Peso de la imagen en bytes: 13247
# Carpeta de origen: human
# rider-73
# Peso de la imagen en bytes: 16546
# Carpeta de origen: human
# rider-74
# Peso de la imagen en bytes: 13277
# Carpeta de origen: human
# rider-75
# Peso de la imagen en bytes: 20653
# Carpeta de origen: human
# rider-76
# Peso de la imagen en bytes: 14692
# Carpeta de origen: human
# rider-77
# Peso de la imagen en bytes: 21884
# Carpeta de origen: human
# rider-78
# Peso de la imagen en bytes: 18408
# Carpeta de origen: human
# rider-79
# Peso de la imagen en bytes: 21577
# Carpeta de origen: human
# rider-8
# Peso de la imagen en bytes: 45757
# Carpeta de origen: human
# rider-80
# Peso de la imagen en bytes: 24305
# Carpeta de origen: human
# rider-81
# Peso de la imagen en bytes: 19563
# Carpeta de origen: human
# rider-82
# Peso de la imagen en bytes: 22505
# Carpeta de origen: human
# rider-83
# Peso de la imagen en bytes: 8500
# Carpeta de origen: human
# rider-84
# Peso de la imagen en bytes: 29242
# Carpeta de origen: human
# rider-85
# Peso de la imagen en bytes: 17468
# Carpeta de origen: human
# rider-86
# Peso de la imagen en bytes: 14248
# Carpeta de origen: human
# rider-87
# Peso de la imagen en bytes: 10498
# Carpeta de origen: human
# rider-88
# Peso de la imagen en bytes: 29339
# Carpeta de origen: human
# rider-89
# Peso de la imagen en bytes: 14520
# Carpeta de origen: human
# rider-9
# Peso de la imagen en bytes: 17026
# Carpeta de origen: human
# rider-90
# Peso de la imagen en bytes: 9896
# Carpeta de origen: human
# rider-91
# Peso de la imagen en bytes: 15350
# Carpeta de origen: human
# rider-92
# Peso de la imagen en bytes: 32323
# Carpeta de origen: human
# rider-93
# Peso de la imagen en bytes: 22086
# Carpeta de origen: human
# rider-94
# Peso de la imagen en bytes: 18167
# Carpeta de origen: human
# rider-95
# Peso de la imagen en bytes: 21709
# Carpeta de origen: human
# rider-96
# Peso de la imagen en bytes: 6487
# Carpeta de origen: human
# rider-97
# Peso de la imagen en bytes: 25194
# Carpeta de origen: human
# rider-98
# Peso de la imagen en bytes: 23037
# Carpeta de origen: human
# rider-99
# Peso de la imagen en bytes: 9656
# Carpeta de origen: human

# %%
#MENÚ
while True:
    print("\nMenú Principal del Árbol Binario:")
    print("1. Insertar Nodo")
    print("2. Eliminar Nodo")
    print("3. Buscar un Nodo utilizando la métrica")
    print("4. Buscar Nodos bajo criterio")
    print("5. Mostrar recorrido por niveles del árbol")
    print("6. Operaciones de Nodo Específico")
    print("7. Salir")

    choice = input("Ingrese su elección (1-7): ").strip()

    if not choice.isdigit() or not 1 <= int(choice) <= 7:
        print("Por favor, ingrese un número válido entre 1 y 7.")
        continue

    if choice == "1":
        valor = input("Ingrese el nombre de la imagen a insertar: ").strip()
        peso = input("Ingrese el peso en bytes de la imagen: ").strip()

        if not peso.isdigit() or int(peso) < 0:
            print("El peso debe ser un número entero positivo. Inténtelo de nuevo.")
            continue

        print("Categorías disponibles: ", ", ".join(arbol.obtener_categorias_disponibles()))
        tipo = input("Ingrese el tipo/categoría de la imagen: ").strip()

        if tipo not in arbol.obtener_categorias_disponibles():
            print("Advertencia: Ha seleccionado una categoría que no está en la lista de categorías disponibles.")
            confirmar = input("¿Desea continuar con esta nueva categoría? (sí/no): ").strip().lower()
            if confirmar != 'sí' and confirmar != 'si':
                continue

        arbol.insertar(valor, int(peso), tipo)
        arbol.graficar_arbol()
        print("Nodo insertado exitosamente y árbol actualizado.")


    elif choice == "2":
        valor = input("Ingrese el nombre de la imagen a eliminar: ").strip()
        if not arbol.buscar_nodo(valor):
            print("El nodo con el valor especificado no existe.")
        else:
            arbol.eliminar_nodo(valor)
            print("Nodo eliminado exitosamente y árbol actualizado.")

    elif choice == "3":
        metrica = input("Ingrese el nombre de la imagen a buscar: ").strip()
        if arbol.buscar_nodo(metrica):
            print(f"Nodo encontrado: {metrica}")
            nodo=arbol.buscar_nodo(metrica)
            ###
            nivel = arbol.obtener_nivel(metrica, arbol.raiz)
            balance = arbol.balance(nodo)
            relaciones= arbol.encontrar_relaciones(metrica)
            if relaciones:
              padre, abuelo, tio = relaciones


            if tio!=None:
                valortio=tio.valor
            else:
                valortio=None
            if abuelo!=None:
                valorabuelo=abuelo.valor
            else:
                valorabuelo=None
            if padre!=None:
                valorpadre=padre.valor
            else:
                valorpadre=None

            print(f"Detalles del nodo:\n- Nivel: {nivel}\n- Factor de balance: {balance}\n- Padre: {valorpadre}\n- Abuelo: {valorabuelo}\n- Tío: {valortio}")
            ###

        else:
            print("Nodo no encontrado.")

    elif choice == "4":
        print("Categorías disponibles: ", ", ".join(arbol.obtener_categorias_disponibles()))
        tipo = input("Ingrese el tipo/categoría para la búsqueda: ").strip()

        if tipo not in arbol.obtener_categorias_disponibles():
            print("Tipo no válido. Inténtelo de nuevo con una categoría válida.")
            continue

        peso_min = input("Ingrese el peso mínimo en bytes: ").strip()
        peso_max = input("Ingrese el peso máximo en bytes: ").strip()

        if not peso_min.isdigit() or not peso_max.isdigit() or int(peso_min) > int(peso_max):
            print("Los pesos deben ser números enteros, y el peso mínimo no puede ser mayor que el peso máximo.")
            continue

        nodos = arbol.buscar_por_tipo_y_peso(tipo, int(peso_min), int(peso_max))
        if nodos:
            print("Nodos encontrados:")
            encontrados = []
            for i, nodo in enumerate(nodos):
              print(f"{i+1}. {nodo.valor}")

              encontrados.append(nodo)
            while True:
              seleccion = input("Seleccione el número del nodo para realizar las operaciones (o '0' para volver atrás): ").strip()
              if seleccion == '0':
                  break
              elif not seleccion.isdigit() or int(seleccion) < 1 or int(seleccion) > len(nodos):
                  print("Selección no válida. Introduzca un número válido o '0' para volver atrás.")
              else:
                nivel = arbol.obtener_nivel(encontrados[int(seleccion)-1].valor, arbol.raiz)
                balance = arbol.balance(encontrados[int(seleccion)-1])
                relaciones= arbol.encontrar_relaciones(encontrados[int(seleccion)-1].valor)
                if relaciones:
                  padre, abuelo, tio = relaciones

                if tio!=None:
                    valortio=tio.valor
                else:
                    valortio=None
                if abuelo!=None:
                    valorabuelo=abuelo.valor
                else:
                    valorabuelo=None
                if padre!=None:
                    valorpadre=padre.valor
                else:
                    valorpadre=None

                print(f"Detalles del nodo:\n- Nivel: {nivel}\n- Factor de balance: {balance}\n- Padre: {valorpadre}\n- Abuelo: {valorabuelo}\n- Tío: {valortio}")


        else:
            print("No se encontraron nodos que cumplan con los criterios.")

    elif choice == "5":
        print("Mostrando el recorrido por niveles del árbol:")
        arbol.mostrar_recorrido_por_niveles()

    elif choice == "6":
        valor = input("Ingrese el nombre del nodo para obtener sus detalles: ").strip()
        nodo = arbol.buscar_nodo(valor)
        if nodo is None:
            print("Nodo no encontrado.")
        else:
            nivel = arbol.obtener_nivel(valor, arbol.raiz)
            balance = arbol.balance(nodo)
            relaciones= arbol.encontrar_relaciones(valor)
            if relaciones:
              padre, abuelo, tio = relaciones
            print(f"Detalles del nodo:\n- Nivel: {nivel}\n- Factor de balance: {balance}\n- Padre: {padre.valor}\n- Abuelo: {abuelo.valor}\n- Tío: {tio.valor}")

    elif choice == "7":
        print("Saliendo del programa...")
        break
# Out:
# Menú Principal del Árbol Binario:
# 1. Insertar Nodo
# 2. Eliminar Nodo
# 3. Buscar un Nodo utilizando la métrica
# 4. Buscar Nodos bajo criterio
# 5. Mostrar recorrido por niveles del árbol
# 6. Operaciones de Nodo Específico
# 7. Salir
# Saliendo del programa...
